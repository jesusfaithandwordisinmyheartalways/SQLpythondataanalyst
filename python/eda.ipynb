# %%
import pandas as pd

# Load the cleaned CSV
df = pd.read_csv("../data/cleaned_sales_data.csv")

# Show the first rows
df.head()
# Out:
#    OrderID        Date        Customer   Product  Quantity  Price  Total  \
# 0     1001  2024-01-03      John Smith  Keyboard       2.0     25   50.0
# 1     1002  2024-01-03    Adam Johnson     Mouse       1.0     15   15.0
# 2     1003  2024-01-04       Sarah Lee    Laptop       1.0    900  900.0
# 3     1004  2024-01-04  Payton Quniton   Monitor       1.0    200  200.0
# 4     1004  2024-01-04    Tony Douglas   Monitor       1.0    200  200.0
#
#                                                Notes
# 0     Keyboard for the price of $25.00 by John Smith
# 1      Mouse for the price of $15.00 by Adam Johnson
# 2       Laptop for the price of $900.00 by Sarah Lee
# 3  Monitor for the price of $200.00 by Payton Qun...
# 4   Monitor for the price of $200.00 by Tony Douglas

# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_sales_data.csv")

df.head()
# Out:
#    OrderID        Date        Customer   Product  Quantity  Price  Total  \
# 0     1001  2024-01-03      John Smith  Keyboard       2.0     25   50.0
# 1     1002  2024-01-03    Adam Johnson     Mouse       1.0     15   15.0
# 2     1003  2024-01-04       Sarah Lee    Laptop       1.0    900  900.0
# 3     1004  2024-01-04  Payton Quniton   Monitor       1.0    200  200.0
# 4     1004  2024-01-04    Tony Douglas   Monitor       1.0    200  200.0
#
#                                                Notes
# 0     Keyboard for the price of $25.00 by John Smith
# 1      Mouse for the price of $15.00 by Adam Johnson
# 2       Laptop for the price of $900.00 by Sarah Lee
# 3  Monitor for the price of $200.00 by Payton Qun...
# 4   Monitor for the price of $200.00 by Tony Douglas

# %%
df.describe()
# Out:
#            OrderID  Quantity       Price       Total
# count     7.000000  7.000000    7.000000    7.000000
# mean   1003.571429  1.142857  196.428571  200.000000
# std       1.718249  0.377964  321.839948  319.752508
# min    1001.000000  1.000000   10.000000   10.000000
# 25%    1002.500000  1.000000   20.000000   20.000000
# 50%    1004.000000  1.000000   25.000000   50.000000
# 75%    1004.500000  1.000000  200.000000  200.000000
# max    1006.000000  2.000000  900.000000  900.000000

# %%
total_revenue = df["Total"].sum()
total_revenue
# Out:
# np.float64(1400.0)

# %%
df.groupby("Product")["Total"].sum()
# Out:
# Product
# Keyboard      75.0
# Laptop       900.0
# Monitor      400.0
# Mouse         15.0
# Mouse Pad     10.0
# Name: Total, dtype: float64

# %%
df.groupby("Customer")["Total"].sum()
# Out:
# Customer
# Adam Johnson       15.0
# Alexa Brown        10.0
# John Smith         50.0
# Payton Quniton    200.0
# Sam Young          25.0
# Sarah Lee         900.0
# Tony Douglas      200.0
# Name: Total, dtype: float64

# %%
import matplotlib.pyplot as plt

df.groupby("Product")["Total"].sum().plot(kind="bar")
plt.title("Revenue by Product")
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
